# %% [markdown]
# # Un peu de déco : le Markdown <a name="mark"></a>
# A. [Travail préalable : copier des notebooks d'aide dans Capytale](#1)
# B. [Travail 1 : insérer une image dans une cellule markdown](#2)
# C. [Travail 2 : titres ,fond, listes  ](#3)
# D. [Travail3 : insérer une vidéo youtube, une animation géogébra](#4)

# %% [markdown]
# ### <font color="green" > Travail préalable : installer des notebooks d'aide dans Capytale<font><a name="1"></a>
#  * ouvrir capytale
#  * Créer une étiquette intitulée aide et de la couleur de votre choix
#  * Taper markdown dans la partie bibliothèque de Capytale.
#  * Copier successivement les trois notebooks apparaissant dans l'image ci dessous
#  * Y ajouter le notebook de Lionel Blin  : mémo Markdown pour les nuls
#  * Dans les paramètres des copies de ces notebooks, y accrocher l'étiquette aide

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <font color="green" > Travail 1 : insérer une image dans une cellule markdown <font><a name="2"></a>
#  aide : https://youtu.be/OA9XSA8RRtY
#  * insérer une image via une copie d'écran dans une cellule Mardown en dessous de celle ci
#  * Faire de même avec une image en ligne
#  * faire de même avec une ou des images présentes sur une clé ou un ordi

# %% [markdown]
#  ### <a href="https://getbootstrap.com/docs/4.0/components/alerts/" class="badge badge-success"><h1>Ressources pour agrémenter le markdown</h1></a>

# %% [markdown]
# ### <font color="green" > Travail 2 : titres ,fond, listes <font><a name="3"></a>
#  Dans des cellules markdown que vous créérez ci dessous :
#  * insérez un titre
#  * insérez un titre de couleur bleu
#  * insérer un titre vert sur fond vert. ( voir ressources et l'exemple ci dessous)

# %% [markdown]
# # <div class="alert alert-warning" role="alert"><center> titre jaunatre sur fond jaune

# %% [markdown]
# ### <font color="green" > Travail 3 : insérer une vidéo youtube, une animation géogébra<font><a name="4"></a>
# aide : https://youtu.be/vHxaZ9eqASg
#     Dans des cellules de code que vous créérez ci dessous, il faudra  :
#  * insérez une vidéo Youtube
#  * insérer une animation géogébra

# %% [markdown]
# Exemple

# %%
from IPython.display import HTML
HTML("""<iframe src="https://www.geogebra.org/classic/zgtyjt5e?embed" width="1800" height="600" allowfullscreen style="border: 1px solid #e4e4e4;border-radius: 4px;" frameborder="0"></iframe>""")
# Out:
# <iframe src="https://www.geogebra.org/classic/zgtyjt5e?embed" width="1800" height="600" allowfullscreen style="border: 1px solid #e4e4e4;border-radius: 4px;" frameborder="0"></iframe>

# %%
from IPython.display import HTML

HTML(""" """)
